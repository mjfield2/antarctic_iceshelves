# %%
import numpy as np
import matplotlib.pyplot as plt
from cmcrameri import cm
from pathlib import Path
import xarray as xr

# %%
name = 'totten'
ds = xr.load_dataset(Path('iceshelves/totten/totten.nc'))

# %%
result = np.load(Path('iceshelves/totten/results_gn/result_157654_0.npy'), allow_pickle=True).item()

# %%
plt.pcolormesh(ds.x, ds.y, result['bed_cache'][-1,...], vmin=-2000, vmax=2000, cmap=cm.bukavu)
plt.axis('scaled')
plt.colorbar()
plt.show()
