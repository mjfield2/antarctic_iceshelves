# %%
# general
import numpy as np
import pandas as pd
import verde as vd
import harmonica as hm
from scipy import interpolate
import xarray as xr
import cmocean
from cmcrameri import cm
import geopandas as gpd
from scipy.stats import mstats
from scipy.interpolate import griddata

# plotting
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec, GridSpecFromSubplotSpec
from matplotlib import animation
from matplotlib.collections import PatchCollection
from matplotlib.patches import Rectangle
from matplotlib_scalebar.scalebar import ScaleBar

# io
from tqdm.auto import tqdm
import os
from pathlib import Path

import sys
sys.path.append(Path('G:/antarctic_iceshelves/iceshelves/src'))

from flowline import flowline

# %%
bm_path = Path('raw_data/BedMachineAntarctica-v4.nc')
antgg_path = Path('raw_data/antgg.nc')
bedmap_path = Path('G:/bedmap/bedmap3_mod.nc')
vel_path = Path('raw_data/antarctic_ice_vel_phase_map_v01.nc')

# MOA: https://nsidc.org/data/nsidc-0730/versions/1
moa_base = Path('raw_data')

# moa coast and grounding line
moa_coast = gpd.read_file(moa_base/'coastlines/moa2014_coastline_v01.shp')
moa_gl = gpd.read_file(moa_base/'coastlines/moa2014_grounding_line_v01.shp')
moa_island = gpd.read_file(moa_base/'coastlines/moa2014_islands_v01.shp')

glkm = moa_gl.to_crs('+proj=stere +lat_0=-90 +lat_ts=-71 +lon_0=0 +x_0=0 +y_0=0 +datum=WGS84 +units=km +no_defs +type=crs')
coastkm = moa_coast.to_crs('+proj=stere +lat_0=-90 +lat_ts=-71 +lon_0=0 +x_0=0 +y_0=0 +datum=WGS84 +units=km +no_defs +type=crs')
islandkm = moa_island.to_crs('+proj=stere +lat_0=-90 +lat_ts=-71 +lon_0=0 +x_0=0 +y_0=0 +datum=WGS84 +units=km +no_defs +type=crs')
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /blue/emackie/michael.field/conda/envs/gravity/share/proj failed

# %%
bm = xr.open_dataset(bm_path)
bm_coarse = bm.coarsen(x=20, y=20, boundary='trim').median()

# %%
region_thw = [-1.6805e6, -1.4205e6, -7.205e5, -3.505e5]
region_abbot = [-2.05e6, -1.7e6, -0.5e6, 0.15e6]
region_george = [-2.2e6, -1.65e6, 0.25e6, 0.9e6]
region_getz = [-1.6e6, -1.15e6, -1.22e6, -0.68e6]
region_larsen = [-2.45e6, -1.92e6, 0.95e6, 1.35e6]
region_maudeast = [-0.1e6, 0.85e6, 1.9e6, 2.3e6]
region_maudwest = [-0.8e6, -0.1e6, 1.35e6, 2.2e6]
region_salz = [-1.05e6, -0.58e6, -1.38e6, -1.08e6]
region_shack = [2.4e6, 2.8e6, -0.7e6, -0.15e6]
region_totten = [2.05e6, 2.38e6, -1.45e6, -0.92e6]
region_pig = [-1.75e6, -1.5e6, -0.45e6, -0.2e6]

# %%
regions = [region_abbot, region_getz, region_george, region_totten, 
           region_salz, region_maudwest, region_maudeast, region_shack, region_larsen, region_pig]

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))

moa_coast.plot(facecolor='lightblue', edgecolor='k', ax=ax, linewidth=0.5, rasterized=True)
moa_gl.plot(facecolor='lightgray', edgecolor='k', ax=ax, linewidth=0.5, rasterized=True)
moa_island.plot(facecolor='lightgray', edgecolor='k', ax=ax, linewidth=0.5, rasterized=True)

rects = []
for r in regions:
    rect = Rectangle((r[0], r[2]), r[1]-r[0], r[3]-r[2])
    rects.append(rect)
collection = PatchCollection(rects, edgecolor='tab:red', facecolor='none', linewidth=2)
ax.add_collection(collection)

ax.axis('off')

plt.savefig(Path('figures/png/inversion_domains.png'), dpi=300, bbox_inches='tight')
plt.savefig(Path('figures/svg/inversion_domains.svg'), dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # AntGG

# %%
ant = xr.open_dataset(antgg_path)
ant
# Out:
# <xarray.Dataset>
# Dimensions:             (y: 1333, x: 1333)
# Coordinates:
#   * y                   (y) float64 3.33e+06 3.325e+06 ... -3.325e+06 -3.33e+06
#   * x                   (x) float64 -3.33e+06 -3.325e+06 ... 3.325e+06 3.33e+06
# Data variables:
#     Boug_anom           (y, x) float64 ...
#     grav_anom           (y, x) float64 ...
#     grav_dist           (y, x) float64 ...
#     gravity_dist_5000m  (y, x) float64 ...
#     stdev               (y, x) float64 ...
#     ell_surf_height     (y, x) float64 ...
#     geoid               (y, x) float64 ...
#     d2T_dr2             (y, x) float64 ...

# %%
fig, ax = plt.subplots(1, 1, figsize=(12,10))
im = ax.pcolormesh(ant.x/1000, ant.y/1000, ant.grav_dist, vmin=-200, vmax=200, cmap='cmo.balance', rasterized=True)
ax.axis('scaled')

glkm.plot(facecolor='none', edgecolor='k', ax=ax, linewidth=0.5)
coastkm.plot(facecolor='none', edgecolor='k', ax=ax, linewidth=0.5)
islandkm.plot(facecolor='none', edgecolor='k', ax=ax, linewidth=0.5)

ax.set_title('ANTGG2021 surface gravity disturbance', fontsize=14)

cbar = plt.colorbar(im, ax=ax, pad=0.02, aspect=40, shrink=0.5, orientation='horizontal', location='bottom')
cbar.ax.tick_params(labelsize=10)
cbar.set_label(label='gravity disturbance [mGal]', fontsize=10)

scalebar = ScaleBar(1, "km", length_fraction=0.1, location='lower left', bbox_to_anchor=(0.15, 0.00),
    bbox_transform=ax.transAxes)
ax.add_artist(scalebar)

rects = []
for r in regions:
    rect = Rectangle((r[0]/1000, r[2]/1000), (r[1]-r[0])/1000, (r[3]-r[2])/1000)
    rects.append(rect)
collection = PatchCollection(rects, edgecolor='darkgreen', facecolor='none', linewidth=2)
ax.add_collection(collection)

ax.set_axis_off()
plt.savefig(Path('figures/png/inversion_domains_grav.png'), dpi=300, bbox_inches='tight')
plt.savefig(Path('figures/svg/inversion_domains_grav.svg'), dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Cross sections

# %%
def get_fine_bedmachine(ds, path):
    grid = xr.open_dataset(bm_path)
    
    xx, yy = np.meshgrid(ds.x, ds.y)
    
    # trim original BedMachine, get coordinates
    x_trim = (grid.x >= np.min(xx)) & (grid.x <= np.max(xx))
    y_trim = (grid.y >= np.min(yy)) & (grid.y <= np.max(yy))
    grid = grid.sel(x=x_trim, y=y_trim)
    xx_bm, yy_bm = np.meshgrid(grid.x.values, grid.y.values)
    
    xx_dens, yy_dens = np.meshgrid(grid.x, grid.y)
    
    kn = vd.KNeighbors(1)
    kn.fit((xx.flatten(), yy.flatten()), ds.inv_msk.values.flatten())
    preds = kn.predict((xx_dens, yy_dens))
    inv_dens = preds.reshape(xx_dens.shape) > 0.5

    return grid, inv_dens

def transform(u, v):
    """
    Log transform quiver arrow lengths
    """
    arrow_lengths = np.sqrt(u*u + v*v)
    len_adjust_factor = np.log10(arrow_lengths + 1) / arrow_lengths
    return u*len_adjust_factor, v*len_adjust_factor

def bedmachine_profile(bm, pred_coords, beds, quantiles=(0.05, 0.95)):
    xx, yy = np.meshgrid(bm.x.values, bm.y.values)
    
    coordinates = np.array([xx.flatten(), yy.flatten()]).T
    
    # use data within 10 km of profile for interpolation
    dist_msk = vd.distance_mask((pred_coords[:,0], pred_coords[:,1]), 10e3, (xx.flatten(), yy.flatten()))
    coordinates = coordinates[dist_msk,:]
    
    bed_profile = griddata(coordinates, bm.bed.values.flatten()[dist_msk], pred_coords)
    surf_profile = griddata(coordinates, bm.surface.values.flatten()[dist_msk], pred_coords)
    thick_profile = griddata(coordinates, bm.thickness.values.flatten()[dist_msk], pred_coords)

    beds_profiles = np.zeros((beds.shape[0], pred_coords.shape[0]))
    for i in tqdm(range(beds.shape[0])):
            beds_profiles[i] =  griddata(coordinates, beds[i].flatten()[dist_msk], pred_coords)

    mean_profile = np.mean(beds_profiles, axis=0)
    std_profile = np.std(beds_profiles, axis=0)
    
    thick_profile = np.where(mean_profile > surf_profile-thick_profile, surf_profile-mean_profile, thick_profile)

    quants = mstats.mquantiles(beds_profiles, prob=quantiles, axis=0)
        
    return bed_profile, surf_profile, thick_profile, beds_profiles, mean_profile, quants

def get_cross_sections(axs, path, x0, y0, stride, total_dist, extend, max_iter=1000, ylow=300, legend=False):

    for item in os.scandir(path):
        if item.name.endswith('.nc')==True:
            ds_path = item.path

    ds = xr.load_dataset(ds_path)
    grid, inv_dens = get_fine_bedmachine(ds, path)

    ensemble = xr.load_dataarray(path/'results_gn/ensemble_geoid_500.nc')
    ensemble_mean = np.mean(ensemble.values, axis=0)
    ensemble_std = np.std(ensemble.values, axis=0)
    ensemble_diff = grid.bed-np.mean(ensemble.values, axis=0)

    xmin = ds.x.values.min()
    xmax = ds.x.values.max()
    ymin = ds.y.values.min()
    ymax = ds.y.values.max()
    
    vel = xr.open_dataset(vel_path)
    vel = vel.sel(x=slice(xmin, xmax), y=slice(ymax, ymin))

    xx_vel, yy_vel = np.meshgrid(vel.x, vel.y)

    vx = vel.VX.values
    vy = vel.VY.values
    
    flow_dist_forward, dists = flowline(xx_vel, yy_vel, vx, vy, x0, y0, stride=stride, mode='distance', total_dist=total_dist, maxdist=5e3, extend=extend, max_iter=max_iter)
    bed_profile, surf_profile, thick_profile, beds, mean_profile, quants = bedmachine_profile(grid, flow_dist_forward[::-1,:], ensemble.values)

    dists /= 1000
    
    water_color = '#21a0cb'
    ice_color = 'lightcyan'
    rock_color = '#a9704f'
    
    ax = axs[0]
    ax.fill_between(dists, surf_profile-thick_profile, surf_profile, color=ice_color, rasterized=True)
    ax.fill_between(dists, np.full(len(dists), np.min(mean_profile))-ylow, mean_profile, color=rock_color, rasterized=True)
    ax.fill_between(dists, mean_profile, surf_profile-thick_profile, color=water_color, rasterized=True)
    ax.plot(dists, surf_profile, c='k')
    ax.plot(dists, surf_profile-thick_profile, c='k')
    
    ax.set_xlim(0, dists[-1])
    ax.set_ylim(np.min(mean_profile)-ylow, np.max(surf_profile)+50)
    # ax.set_xlabel('Distance along profile [km]')
    ax.set_ylabel('Elevation [m]')
    
    ax.plot(dists, beds[0], c='k', alpha=0.3, linewidth=0.5, label='ensemble member')
    for i in range(1, beds.shape[0]):
        ax.plot(dists, beds[i], c='k', alpha=0.3, linewidth=0.5)
    
    ax.plot(dists, bed_profile, c='lawngreen', label='BedMachine')
    ax.plot(dists, mean_profile, c='magenta', label='ensemble mean')
    ax.plot(dists, quants[0], c='orange', linestyle='dashed', label='0.5 / 0.95 percentiles')
    ax.plot(dists, quants[1], c='orange', linestyle='dashed')

    if legend==True:
        ax.legend(framealpha=1, fontsize=14, loc='lower left', fancybox=False, handlelength=1.3, handleheight=1, frameon=True, facecolor='whitesmoke', 
                  markerfirst=False, labelspacing=0.2)
    
    ax = axs[1]
    ax.pcolormesh(ensemble.x/1000, ensemble.y/1000, ensemble_mean, cmap=cm.bukavu, vmin=-2000, vmax=2000, rasterized=True)
    cs1 = ax.contour(grid.x/1000, grid.y/1000, inv_dens, levels=[0], colors='k', antialiased=True, linewidths=1, alpha=0.7)
    ax.plot(flow_dist_forward[:,0]/1000, flow_dist_forward[:,1]/1000, 'r-')
    ax.plot(flow_dist_forward[0,0]/1000, flow_dist_forward[0,1]/1000, 'ro', markersize=4)
    ax.axis('scaled')
    ax.set_ylabel('Y [km]')
    ax.set_xlabel('X [km]')

# %%
cross_sections = []
cross_sections.append(get_cross_sections(Path('iceshelves/abbot'), -1.8e6, -0.19e6, 200, 150e3, 0))
cross_sections.append(get_cross_sections(Path('iceshelves/george'), -1.7e6, 0.68e6, 200, 250e3, 50))
cross_sections.append(get_cross_sections(Path('iceshelves/getz'), -1.42e6, -0.82e6, 200, 250e3, 50))
cross_sections.append(get_cross_sections(Path('iceshelves/larsen'), -2.12e6, 0.96e6, 200, 300e3, 50, max_iter=1500))
cross_sections.append(get_cross_sections(Path('iceshelves/maudeast'), -0.045e6, 1.965e6, 500, 300e3, 20, max_iter=1500))
cross_sections.append(get_cross_sections(Path('iceshelves/maudwest'), -0.5e6, 1.51e6, 500, 280e3, 5, max_iter=1500))
cross_sections.append(get_cross_sections(Path('iceshelves/salzberger'), -0.85e6, -1.25e6, 200, 150e3, 5))
cross_sections.append(get_cross_sections(Path('iceshelves/shackleton'), 2.52e6, -0.41e6, 200, 150e3, 20))
cross_sections.append(get_cross_sections(Path('iceshelves/pineisland_new'), -1.69e6, -0.293e6, 200, 150e3, 50))
cross_sections.append(get_cross_sections(Path('iceshelves/totten'), 2.28e6, -1e6, 200, 150e3, 50))
# Out:
# ...
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
fig = plt.figure(figsize=(14,27), constrained_layout=True)

gs = GridSpec(10, 2, width_ratios=[1, 0.3], figure=fig)

axs = []
for i in range(10):
    ax1 = fig.add_subplot(gs[i,0])
    ax2 = fig.add_subplot(gs[i,1])
    axs.append([ax1, ax2])
    
# for i, (axs_i, cross_section) in enumerate(zip(axs, cross_sections)):
#     if i==len(axs)-1:
#         plot_cross_sections(axs_i, *cross_section, legend=True)
#     else:
#         plot_cross_sections(axs_i, *cross_section)
get_cross_sections(axs[0], Path('iceshelves/abbot'), -1.8e6, -0.19e6, 200, 150e3, 0)
get_cross_sections(axs[1], Path('iceshelves/george'), -1.7e6, 0.68e6, 200, 250e3, 50)
get_cross_sections(axs[2], Path('iceshelves/getz'), -1.42e6, -0.82e6, 200, 250e3, 50)
get_cross_sections(axs[3], Path('iceshelves/larsen'), -2.12e6, 0.96e6, 200, 300e3, 50, max_iter=1500)
get_cross_sections(axs[4], Path('iceshelves/maudeast'), -0.045e6, 1.965e6, 500, 300e3, 20, max_iter=1500)
get_cross_sections(axs[5], Path('iceshelves/maudwest'), -0.5e6, 1.51e6, 500, 280e3, 5, max_iter=1500)
get_cross_sections(axs[6], Path('iceshelves/salzberger'), -0.85e6, -1.25e6, 200, 150e3, 5)
get_cross_sections(axs[7], Path('iceshelves/shackleton'), 2.52e6, -0.41e6, 200, 150e3, 20)
get_cross_sections(axs[8], Path('iceshelves/pineisland_new'), -1.69e6, -0.293e6, 200, 150e3, 50)
get_cross_sections(axs[9], Path('iceshelves/totten'), 2.28e6, -1e6, 200, 150e3, 50, legend=True)

axs[0][0].set_xlabel('Distance along profile [km]')

plt.savefig(Path('figures/png/cross_sections.png'), dpi=300, bbox_inches='tight')
plt.savefig(Path('figures/svg/cross_sections.svg'), dpi=300, bbox_inches='tight')
plt.show()
# Out:
# ...
#   0%|          | 0/200 [00:00<?, ?it/s]
